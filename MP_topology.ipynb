# %% [markdown]
# # Bonding and topology determination in the Materials Project database

# %%
import json
import os
import random
import warnings

import juliacall

import pymatgen
from pymatgen.analysis.chemenv.coordination_environments.chemenv_strategies import SimplestChemenvStrategy, MultiWeightsChemenvStrategy
from pymatgen.analysis.chemenv.coordination_environments.coordination_geometry_finder import LocalGeometryFinder
from pymatgen.analysis.chemenv.coordination_environments.structure_environments import LightStructureEnvironments
from pymatgen.analysis.graphs import StructureGraph
from pymatgen.analysis.local_env import CrystalNN
from pymatgen.core import Structure
from pymatgen.ext.matproj import MPRester
from pymatgen.io.cif import CifWriter

from tqdm.notebook import tqdm

random.seed("Call me Ishmael")
print("Using pymatgen version:", pymatgen.core.__version__)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# Using pymatgen version: 2025.2.18

# %%
jl = juliacall.newmodule("NotebookModule")
jl.seval("using CrystalNets")
jl.CrystalNets.toggle_export(False)

print("Using Julia version:", jl.seval("VERSION"))
print("Running from directory:", jl.seval("Sys.BINDIR"))
# Out:
# Using Julia version: 1.11.3
# Running from directory: /opt/julia-1.11.3/bin

# %%
with open(os.path.expanduser("~/.mpapikey"), "r") as f:
    apikey = f.read().strip()

# %%
try:
    os.mkdir("cif")
except FileExistsError as e:
    pass

try:
    os.mkdir("cif_chemenv")
except FileExistsError as e:
    pass

# %%
crystallnn = CrystalNN()
crystallnn_noweight = CrystalNN(x_diff_weight = 0)

chemenv_strategy = SimplestChemenvStrategy(distance_cutoff=1.4, angle_cutoff=0.3)
# We cannot use the more powerful multi-weight strategy, because it creates fractional coordination environment
# chemenv_strategy = MultiWeightsChemenvStrategy.stats_article_weights_parameters()


nonmetals = {'O', 'S', 'Se', 'Te', 'Po', 'F', 'Cl', 'Br', 'I', 'At', 'N', 'P', 'As', 'Sb', 'C', 'Si', 'Ge', 'B', 'H', 'He', 'Ne', 'Ar', 'Kr', 'Xe'}

def isIntermetallic(struct):
    el = set(str(x) for x in struct.elements)
    return len(el & nonmetals) == 0


def make_labels_unique(struct):
    from collections import Counter
    
    labels = Counter(site.label for site in struct.sites)
    counter = {}
    for i, site in enumerate(struct.sites):
        label = site.label
        if labels[label] > 1 or label.isalpha():
            c = counter.get(label, 0)
            site.label = f"{label}{c}" if label.isalpha() else f"{label}_{c}"
            c = c + 1
            counter[label] = c


def jimage_to_site_symmetry(jimage):
    i, j, k = jimage
    return f"1_{5+i}{5+j}{5+k}"


def writeToCifFile(bonded_struct, file):
    cif_writer = CifWriter(bonded_struct.structure)
    cif = str(cif_writer)
    cif += """loop_
_geom_bond_atom_site_label_1
_geom_bond_atom_site_label_2
_geom_bond_distance
_geom_bond_site_symmetry_2
"""

    for n, site in enumerate(bonded_struct.structure.sites):
        for connected in bonded_struct.get_connected_sites(n):
            # Make sure we only output each bond once
            if site.label <= connected.site.label:
                cif += f"{site.label} {connected.site.label} {connected.dist:.6f} {jimage_to_site_symmetry(connected.jimage)}\n"

    file.write(cif)


def bonded_structure_from_lse(lse: LightStructureEnvironments) -> StructureGraph:
    """
    Convert a LightStructureEnvironments from chemenv to a StructureGraph
    """
    graph = StructureGraph.from_empty_graph(lse.structure, name="bonds")

    for nset in lse.neighbors_sets:
        assert len(nset) == 1
        for neighbor in nset[0].neighb_indices_and_images:
            graph.add_edge(
                from_index=nset[0].isite,
                from_jimage=(0, 0, 0),
                to_index=neighbor["index"],
                to_jimage=neighbor["image_cell"],
                weight=1,
                edge_properties=None,
                warn_duplicates=False,
            )

    graph.set_node_attributes()
    return graph


def analyse_bonding(mat, method = "CrystalNN"):
    if method != "CrystalNN" and method != "ChemEnv":
        raise ValueError("invalid method name")

    # Magnetic moments trigger a bug in CifWriter, so we remove them here
    # https://github.com/materialsproject/pymatgen/issues/3772
    if "magmom" in mat.structure.site_properties:
        mat.structure.remove_site_property("magmom")

    # All labels should be unique (otherwise bond specifications will fail)
    make_labels_unique(mat.structure)
    labels = [site.label for site in mat.structure.sites]
    if len(labels) != len(set(labels)):
        raise ValueError("labels are not unique in structure")

    while True:
        bonded_struct = None
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            try:
                if method == "ChemEnv":
                    lgf = LocalGeometryFinder()
                    lgf.setup_structure(structure=mat.structure)
                    se = lgf.compute_structure_environments(
                        maximum_distance_factor=1.41, only_cations=False
                    )
                    lse = LightStructureEnvironments.from_structure_environments(
                        strategy=chemenv_strategy, structure_environments=se
                    )
                    bonded_struct = bonded_structure_from_lse(lse)
                else:
                    if isIntermetallic(mat):
                        bonded_struct = crystallnn_noweight.get_bonded_structure(mat.structure)
                    else:
                        bonded_struct = crystallnn.get_bonded_structure(mat.structure)

            except Exception as e:
                print(f"{method} failed for {mat.material_id}: {e}")
                return None

        coord = set()
        bonds = set()
        rerun_flag = False
        for n, site in enumerate(bonded_struct.structure.sites):
            neighbors = bonded_struct.get_connected_sites(n)
            # We cannot use get_coordination_of_site() because of a bug:
            # https://github.com/materialsproject/pymatgen/issues/3888#issuecomment-2232571072
            coord.add((str(site.specie), len(neighbors)))
            for connected in neighbors:
                if site.specie <= connected.site.specie:
                    bonds.add((str(site.specie), str(connected.site.specie)))
                if site.label == connected.site.label:
                    # If an atom is bonded to its own image, then CrystalNets will not like it
                    # and we need to make rerun on a supercell
                    rerun_flag = True

        if rerun_flag:
            # If we found an atom bonded to itself, 
            mat.structure.make_supercell(2, in_place=True)
            make_labels_unique(mat.structure)
        else:
            # Otherwise we're done
            break

    # Write bonded structure as CIF; output directory depends on method
    if method == "ChemEnv":
        dirname = "cif_chemenv"
    else:
        dirname = "cif"
    with open(f"{dirname}/{mat.material_id}.cif", "w") as f:
        writeToCifFile(bonded_struct, f)

    return {"material_id": str(mat.material_id),
            "formula_pretty": mat.formula_pretty,
            "nelements": mat.nelements,
            "theoretical": mat.theoretical,
            "is_stable": mat.is_stable,
            "crystal_system": str(mat.symmetry.crystal_system),
            "space_group": mat.symmetry.number,
            "coordination": coord,
            "bonds": bonds}

# %%
# Test our analysis method on one material
with MPRester(apikey) as mpr:
    mp_data = mpr.materials.summary.search(
        material_ids=["mp-3934"],
        fields=["material_id", "builder_meta", "deprecated", "formula_pretty", "nelements", "elements", "structure", "theoretical", "symmetry"]
    )

    assert len(mp_data) == 1
    res = analyse_bonding(mp_data[0])
    print(res)

    res = analyse_bonding(mp_data[0], "ChemEnv")
    print(res)
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/1 [00:00<?, ?it/s]
# {'material_id': 'mp-3934', 'formula_pretty': 'Cu3PS4', 'nelements': 3, 'theoretical': False, 'is_stable': None, 'crystal_system': 'Orthorhombic', 'space_group': 31, 'coordination': {('S', 4), ('Cu', 4), ('P', 4)}, 'bonds': {('Cu', 'S'), ('P', 'S')}}
# {'material_id': 'mp-3934', 'formula_pretty': 'Cu3PS4', 'nelements': 3, 'theoretical': False, 'is_stable': None, 'crystal_system': 'Orthorhombic', 'space_group': 31, 'coordination': {('S', 4), ('Cu', 4), ('P', 4)}, 'bonds': {('Cu', 'S'), ('P', 'S')}}

# %%
with MPRester(apikey) as mpr:
    mp_data = mpr.materials.summary.search(
        deprecated=False,
        fields=["material_id", "builder_meta", "deprecated", "formula_pretty", "nelements", "elements", "structure", "theoretical", "symmetry"]
    )

print("Database version", mpr.get_database_version())
print("Number of materials found:", len(mp_data))

# Check that we did not get any deprecated material
# See https://github.com/materialsproject/api/issues/964
assert sum(1 for x in mp_data if x.deprecated) == 0
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/170470 [00:00<?, ?it/s]
# Database version 2025.02.12.post
# Number of materials found: 170470

# %%
n_gnome = sum(1 for x in mp_data if x.builder_meta.batch_id and "gnome" in x.builder_meta.batch_id)
n_ccbynd = sum(1 for x in mp_data if x.builder_meta.license == "BY-NC")

print("Number of GnoME structures:", n_gnome)
print("Number of non-GnoME structures:", len(mp_data) - n_gnome)
print("Number of CC-BY-ND structures:", n_ccbynd)
# Out:
# Number of GnoME structures: 15483
# Number of non-GnoME structures: 154987
# Number of CC-BY-ND structures: 15483

# %%
data = {}

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="No Pauling electronegativity")
    for mat in tqdm(mp_data, smoothing=0.01, mininterval=1):
        x = analyse_bonding(mat)
        if x is not None:
            data[mat.material_id] = x

print("Number of systems analyzed:", len(data))
# Out:
#   0%|          | 0/170470 [00:00<?, ?it/s]
# CrystalNN failed for mp-994911: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1210439: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1247838: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1213668: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1215144: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1180797: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1247813: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1212347: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1214815: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1215160: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1180180: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1101037: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1182718: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1182772: No Voronoi neighbors found for site - try increasing cutoff
# CrystalNN failed for mp-1212042: No Voronoi neighbors found for site - try increasing cutoff
# Number of systems analyzed: 170455

# %%
sample_data = random.sample(mp_data, 5000)
data_chemenv = {}

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", message="No Pauling electronegativity")
    for mat in tqdm(sample_data, smoothing=0.01, mininterval=1):
        x = analyse_bonding(mat, "ChemEnv")
        if x is not None:
            data_chemenv[mat.material_id] = x

print("Number of systems analyzed:", len(data_chemenv))
# Out:
#   0%|          | 0/5000 [00:00<?, ?it/s]
# ChemEnv failed for mp-1197448: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1096242: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p1(v5):   2.7 8.1e-17 1.7e-16   7.4
# - p3(v4):  -5.3     0     0    28
# - p2(v3):  -2.7 -8.1e-17 -1.7e-16   7.4
# - p6(v2):   7.9 -8.1e-17 2.7e-16    63
# - p5(v1):  -7.9 8.1e-17 -2.7e-16    63
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2051584325  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 63  Error-roundoff 7.7e-14  _one-merge 6.9e-13
#   _near-inside 3.5e-12  Visible-distance 4.6e-13  U-max-coplanar 4.6e-13
#   Width-outside 9.3e-13  _wide-facet 2.8e-12  _maxoutside 9.3e-13
#
# ChemEnv failed for mp-761178: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1096241: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):  -3.1 4.8e-17 -1.9e-16   9.4
# - p1(v4):   3.1 -5.3e-17 1.6e-16   9.4
# - p4(v3):  -5.8     0     0    34
# - p5(v2):   8.5 4.8e-17 -1.9e-16    73
# - p6(v1):  -8.5 1.7e-16 1.6e-16    73
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2052357447  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 73  Error-roundoff 8.9e-14  _one-merge 8e-13
#   _near-inside 4e-12  Visible-distance 5.3e-13  U-max-coplanar 5.3e-13
#   Width-outside 1.1e-12  _wide-facet 3.2e-12  _maxoutside 1.1e-12
#
# ChemEnv failed for mp-1093799: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):  -3.1     0  -1.8    13
# - p1(v4):   3.1     0   1.8    13
# - p0(v3):     0     0     0     0
# - p5(v2):   8.2     0   4.7    89
# - p6(v1):  -8.2     0  -4.7    89
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2056491969  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 89  Error-roundoff 1.1e-13  _one-merge 1e-12
#   _near-inside 5e-12  Visible-distance 6.7e-13  U-max-coplanar 6.7e-13
#   Width-outside 1.3e-12  _wide-facet 4e-12  _maxoutside 1.3e-12
#
# ChemEnv failed for mp-1224497: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1023955: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1030160: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-20140: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1244893: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-2218334: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1228259: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1027015: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1189046: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1030107: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1096566: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p4(v5):  -5.3     0     0    28
# - p2(v4):  -2.7 3e-17 -2e-16     7
# - p1(v3):   2.7 -8.4e-17 -4.2e-17     7
# - p5(v2):     8 2.5e-16 2.5e-16    64
# - p6(v1):    -8 -2.5e-16 -2.5e-16    64
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2068593009  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 64  Error-roundoff 7.8e-14  _one-merge 7.1e-13
#   _near-inside 3.5e-12  Visible-distance 4.7e-13  U-max-coplanar 4.7e-13
#   Width-outside 9.4e-13  _wide-facet 2.8e-12  _maxoutside 9.4e-13
#
# ChemEnv failed for mp-1096504: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   -29    10 0.095 9.5e+02
# - p1(v4):   -24    10   3.2 6.8e+02
# - p0(v3):   -26    10   1.9 7.9e+02
# - p5(v2):   -18    10   6.4 4.8e+02
# - p6(v1):   -35    10    -3 1.3e+03
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2068895535  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 8.3e+02  Error-roundoff 1.5e-12  _one-merge 1.4e-11
#   _near-inside 6.8e-11  Visible-distance 9e-12  U-max-coplanar 9e-12
#   Width-outside 1.8e-11  _wide-facet 5.4e-11  _maxoutside 1.8e-11
#
# ChemEnv failed for mp-1097426: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   2.6 9.7e-17 -5.5e-17   6.6
# - p3(v4):  -2.6 -4.6e-17 7.5e-17   6.6
# - p4(v3):   9.2 4e-16 -1.5e-16    86
# - p6(v2):    12     0     0 1.4e+02
# - p5(v1):  -5.9     0     0    35
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2069567815  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 1.4e+02  Error-roundoff 1.7e-13  _one-merge 1.5e-12
#   _near-inside 7.5e-12  Visible-distance 1e-12  U-max-coplanar 1e-12
#   Width-outside 2e-12  _wide-facet 6e-12  _maxoutside 2e-12
#
# ChemEnv failed for mp-1093950: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   4.8     0     0    23
# - p4(v4):   7.3 -1.1e-16 -2.4e-16    53
# - p3(v3):  -2.3 -1.1e-16 2.1e-16   5.5
# - p8(v2):    12 -3.1e-16 7.1e-16 1.4e+02
# - p7(v1):  -7.3 3.6e-16 -2.3e-16    53
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2071836760  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 1.4e+02  Error-roundoff 1.7e-13  _one-merge 1.5e-12
#   _near-inside 7.7e-12  Visible-distance 1e-12  U-max-coplanar 1e-12
#   Width-outside 2.1e-12  _wide-facet 6.2e-12  _maxoutside 2.1e-12
#
# ChemEnv failed for mp-1193046: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1029139: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1093619: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):  -2.8 -3.7e-17 -1.2e-16     8
# - p4(v4):  -5.7     0     0    33
# - p3(v3):   5.7     0     0    33
# - p5(v2):   8.6 4.1e-16 -1.2e-16    74
# - p6(v1):  -8.6 -2.4e-16 -3.9e-16    74
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2083836958  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 74  Error-roundoff 9.1e-14  _one-merge 8.2e-13
#   _near-inside 4.1e-12  Visible-distance 5.4e-13  U-max-coplanar 5.4e-13
#   Width-outside 1.1e-12  _wide-facet 3.3e-12  _maxoutside 1.1e-12
#
# ChemEnv failed for mp-1096719: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   5.9     0     0    35
# - p4(v4):    12     0     0 1.4e+02
# - p1(v3):   8.8 -4e-16 -1e-17    78
# - p5(v2):    15 3.1e-16 -6.4e-16 2.2e+02
# - p6(v1):  -2.9 4.4e-17 -1e-17   8.6
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2083853765  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 2.2e+02  Error-roundoff 2.5e-13  _one-merge 2.3e-12
#   _near-inside 1.1e-11  Visible-distance 1.5e-12  U-max-coplanar 1.5e-12
#   Width-outside 3.1e-12  _wide-facet 9.2e-12  _maxoutside 3.1e-12
#
# ChemEnv failed for mp-1207370: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):     0     0     0     0
# - p22(v4):   1.3   8.1     0    68
# - p21(v3):  -1.3  -8.1     0    68
# - p27(v2):   9.3 -0.37     0    88
# - p28(v1):  -9.3  0.37     0    88
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2103349885  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 88  Error-roundoff 1.1e-13  _one-merge 1e-12
#   _near-inside 5.1e-12  Visible-distance 6.8e-13  U-max-coplanar 6.8e-13
#   Width-outside 1.4e-12  _wide-facet 4.1e-12  _maxoutside 1.4e-12
#
# ChemEnv failed for mp-1201627: object of type 'NoneType' has no len()
# ChemEnv failed for mp-2224719: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1093925: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p1(v5):     0     0     0     0
# - p3(v4):  -2.8 -8.6e-18 1.3e-16   7.8
# - p0(v3):   2.8 1.6e-17 7.4e-17   7.8
# - p6(v2):    12     0     0 1.5e+02
# - p5(v1):    -6     0     0    36
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2111131526  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 1.5e+02  Error-roundoff 1.7e-13  _one-merge 1.6e-12
#   _near-inside 7.8e-12  Visible-distance 1e-12  U-max-coplanar 1e-12
#   Width-outside 2.1e-12  _wide-facet 6.3e-12  _maxoutside 2.1e-12
#
# ChemEnv failed for mp-2647020: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1027801: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1027147: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1030454: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1202044: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1023900: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1096184: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):     0   7.1     0    50
# - p0(v4): -1.9e-17    11 3.9e-16 1.2e+02
# - p1(v3):     0    14     0 2e+02
# - p4(v2): 4.8e-17   3.2 7.6e-17    10
# - p3(v1): -5.1e-16    17 6.4e-16 3e+02
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2132375574  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 2.9e+02  Error-roundoff 3.5e-13  _one-merge 3.2e-12
#   _near-inside 1.6e-11  Visible-distance 2.1e-12  U-max-coplanar 2.1e-12
#   Width-outside 4.2e-12  _wide-facet 1.3e-11  _maxoutside 4.2e-12
#
# ChemEnv failed for mp-1028951: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1030580: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1097576: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p1(v5):   2.8 -5.6e-17 7.3e-17   7.9
# - p4(v4):  -5.7     0     0    32
# - p3(v3):   5.7     0     0    32
# - p5(v2):   8.6 3.4e-16 3.3e-16    73
# - p6(v1):  -8.6 -2.3e-16 3.1e-16    73
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2137888270  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 73  Error-roundoff 9e-14  _one-merge 8.1e-13
#   _near-inside 4e-12  Visible-distance 5.4e-13  U-max-coplanar 5.4e-13
#   Width-outside 1.1e-12  _wide-facet 3.2e-12  _maxoutside 1.1e-12
#
# ChemEnv failed for mp-1097667: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   2.9 -1.8e-17 1.3e-16   8.3
# - p4(v4):    12     0     0 1.4e+02
# - p1(v3):   8.9 -1.7e-16 -1.2e-17    78
# - p5(v2):    15 2.7e-17 8.2e-16 2.1e+02
# - p6(v1):  -2.9 5.2e-17 -1.2e-17   8.3
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2138173989  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 2.1e+02  Error-roundoff 2.5e-13  _one-merge 2.3e-12
#   _near-inside 1.1e-11  Visible-distance 1.5e-12  U-max-coplanar 1.5e-12
#   Width-outside 3e-12  _wide-facet 9.1e-12  _maxoutside 3e-12
#
# ChemEnv failed for mp-1027171: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1096230: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p4(v5):  -2.7 -2.3e-17 1.7e-16   7.6
# - p3(v4):   8.2 -2.3e-17 -2.7e-16    68
# - p0(v3):   2.7 4.1e-17 -3.5e-17   7.6
# - p5(v2):    11     0     0 1.2e+02
# - p6(v1):  -5.5     0     0    30
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2138728620  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 1.2e+02  Error-roundoff 1.4e-13  _one-merge 1.3e-12
#   _near-inside 6.5e-12  Visible-distance 8.7e-13  U-max-coplanar 8.7e-13
#   Width-outside 1.7e-12  _wide-facet 5.2e-12  _maxoutside 1.7e-12
#
# ChemEnv failed for mp-1182980: QH6013 qhull input error: input is less than 4-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2142711879  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 2.5e+02  Error-roundoff 2.9e-13  _one-merge 2.6e-12
#   _near-inside 1.3e-11  Visible-distance 1.7e-12  U-max-coplanar 1.7e-12
#   Width-outside 3.5e-12  _wide-facet 1e-11  _maxoutside 3.5e-12
#
# ChemEnv failed for mp-1093671: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p3(v5):     0    -6     0    35
# - p2(v4): 9.5e-17  -3.1 -8.8e-17   9.8
# - p6(v3): 2.3e-17  -8.8 4e-16    77
# - p5(v2): 3.2e-16   8.8 -8.8e-17    77
# - p1(v1): -9.4e-17   3.1 -6.2e-17   9.8
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 2143737106  voronoi  offFile  _pre-merge  _zero-centrum  Pgood
#   Fvoronoi  _max-width 77  Error-roundoff 9.4e-14  _one-merge 8.5e-13
#   _near-inside 4.2e-12  Visible-distance 5.6e-13  U-max-coplanar 5.6e-13
#   Width-outside 1.1e-12  _wide-facet 3.4e-12  _maxoutside 1.1e-12
#
# ChemEnv failed for mp-3206840: object of type 'NoneType' has no len()
# ChemEnv failed for mp-754101: object of type 'NoneType' has no len()
# ChemEnv failed for mp-3209559: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1025747: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1026356: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1204736: object of type 'NoneType' has no len()
# ChemEnv failed for mp-643797: object of type 'NoneType' has no len()
# ChemEnv failed for mp-3207808: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1097359: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p4(v5):     0    14     0 1.9e+02
# - p1(v4): 1.6e-17   3.3 -1.9e-17    11
# - p3(v3):     0     0     0     0
# - p2(v2): 1.7e-16    11 2e-16 1.1e+02
# - p0(v1):     0   6.9     0    48
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 22337923  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.9e+02  Error-roundoff 2.3e-13  _one-merge 2e-12
#   _near-inside 1e-11  Visible-distance 1.4e-12  U-max-coplanar 1.4e-12
#   Width-outside 2.7e-12  _wide-facet 8.1e-12  _maxoutside 2.7e-12
#
# ChemEnv failed for mp-1097380: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p6(v5): 9e-17   9.4 4.3e-16    88
# - p3(v4):     0  -6.4     0    41
# - p5(v3): -9e-17  -9.4 -4.3e-16    88
# - p1(v2): 9e-17  -3.4 -1.5e-17    12
# - p2(v1): -9e-17   3.4 1.5e-17    12
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 22623642  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 88  Error-roundoff 1.1e-13  _one-merge 9.6e-13
#   _near-inside 4.8e-12  Visible-distance 6.4e-13  U-max-coplanar 6.4e-13
#   Width-outside 1.3e-12  _wide-facet 3.8e-12  _maxoutside 1.3e-12
#
# ChemEnv failed for mp-1096461: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   2.3 4.9e-17 -5e-17   5.1
# - p1(v4):   7.7 -3.5e-16 -3.1e-16    59
# - p5(v3):    12 -3.4e-16 6.2e-16 1.5e+02
# - p7(v2):    15 8.9e-16 -8.9e-16 2.2e+02
# - p8(v1):    -5     0     0    25
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 23144659  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 2.2e+02  Error-roundoff 2.6e-13  _one-merge 2.4e-12
#   _near-inside 1.2e-11  Visible-distance 1.6e-12  U-max-coplanar 1.6e-12
#   Width-outside 3.2e-12  _wide-facet 9.5e-12  _maxoutside 3.2e-12
#
# ChemEnv failed for mp-1207340: QH6214 qhull input error: not enough points(2) to construct initial simplex (need 5)
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 23985009  voronoi  offFile  _pre-merge  _zero-centrum  _maxoutside  0
#
# ChemEnv failed for mp-16836: object of type 'NoneType' has no len()
# ChemEnv failed for mp-13608: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1097261: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p1(v5):   2.6 -1e-16 5e-17   6.6
# - p6(v4):  -7.2 1.2e-16 -3.9e-16    51
# - p5(v3):   7.2 2.4e-16 -3.2e-16    51
# - p8(v2):   9.7     0     0    95
# - p7(v1):  -9.7     0     0    95
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 26741357  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 95  Error-roundoff 1.1e-13  _one-merge 1e-12  _near-inside 5.2e-12
#   Visible-distance 6.9e-13  U-max-coplanar 6.9e-13  Width-outside 1.4e-12
#   _wide-facet 4.1e-12  _maxoutside 1.4e-12
#
# ChemEnv failed for mp-1097521: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   2.9 -9.6e-17 1e-16   8.5
# - p3(v4):  -2.9 7.3e-17 -6e-18   8.5
# - p4(v3):   9.2 -1.5e-16 4.4e-16    84
# - p6(v2):    12     0     0 1.5e+02
# - p5(v1):  -6.1     0     0    37
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 27682549  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.5e+02  Error-roundoff 1.7e-13  _one-merge 1.6e-12
#   _near-inside 7.9e-12  Visible-distance 1e-12  U-max-coplanar 1e-12
#   Width-outside 2.1e-12  _wide-facet 6.3e-12  _maxoutside 2.1e-12
#
# ChemEnv failed for mp-1027080: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1025925: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1097485: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):     0     0     0     0
# - p3(v4):  -5.6     0     0    31
# - p1(v3):   2.8 -1.1e-16 -5.8e-17   7.8
# - p5(v2):   8.4 3.7e-16 -3.9e-17    70
# - p6(v1):  -8.4 3.8e-16 1.9e-16    70
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 39615519  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 70  Error-roundoff 8.6e-14  _one-merge 7.7e-13
#   _near-inside 3.9e-12  Visible-distance 5.1e-13  U-max-coplanar 5.1e-13
#   Width-outside 1e-12  _wide-facet 3.1e-12  _maxoutside 1e-12
#
# ChemEnv failed for mp-1096431: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1027517: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1096349: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   2.4 -4.3e-17 -1.1e-16   5.7
# - p1(v4):  -2.4 -7.6e-17 9.4e-17   5.7
# - p3(v3):    -5     0     0    25
# - p6(v2):   7.7 -3e-16 -3.5e-16    59
# - p5(v1):  -7.7 3e-16 3.5e-16    59
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 56556975  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 59  Error-roundoff 7.3e-14  _one-merge 6.6e-13
#   _near-inside 3.3e-12  Visible-distance 4.4e-13  U-max-coplanar 4.4e-13
#   Width-outside 8.7e-13  _wide-facet 2.6e-12  _maxoutside 8.7e-13
#
# ChemEnv failed for mp-1093595: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):     0     0     0     0
# - p3(v4):  -5.3     0     0    28
# - p4(v3):   5.3     0     0    28
# - p5(v2):   8.1 -3.5e-16 8.1e-17    66
# - p6(v1):  -8.1 1.6e-16 3e-16    66
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 57935149  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 66  Error-roundoff 8.1e-14  _one-merge 7.3e-13
#   _near-inside 3.6e-12  Visible-distance 4.8e-13  U-max-coplanar 4.8e-13
#   Width-outside 9.7e-13  _wide-facet 2.9e-12  _maxoutside 9.7e-13
#
# ChemEnv failed for mp-1096300: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p1(v5):     0     0     0     0
# - p3(v4):  -2.8 2.2e-18 -7.5e-17   7.9
# - p0(v3):   2.8 9.5e-17 1.2e-16   7.9
# - p6(v2):    12     0     0 1.4e+02
# - p5(v1):  -5.8     0     0    34
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 58674657  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.4e+02  Error-roundoff 1.6e-13  _one-merge 1.5e-12
#   _near-inside 7.3e-12  Visible-distance 9.8e-13  U-max-coplanar 9.8e-13
#   Width-outside 2e-12  _wide-facet 5.9e-12  _maxoutside 2e-12
#
# ChemEnv failed for mp-1027339: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1096035: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):     3 1.3e-17 -2e-16     9
# - p3(v4):    -3 -1.3e-17 2e-16     9
# - p4(v3):   9.5 -2.4e-16 -2.4e-16    90
# - p6(v2):    12     0     0 1.6e+02
# - p5(v1):  -6.2     0     0    39
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 59599042  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.6e+02  Error-roundoff 1.9e-13  _one-merge 1.7e-12
#   _near-inside 8.4e-12  Visible-distance 1.1e-12  U-max-coplanar 1.1e-12
#   Width-outside 2.2e-12  _wide-facet 6.7e-12  _maxoutside 2.2e-12
#
# ChemEnv failed for mp-1095959: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   2.3 5.9e-17 6.8e-17   5.2
# - p3(v4):  -2.3 1.1e-17 7.6e-17   5.2
# - p4(v3):   8.1 -4.3e-16 -3.7e-16    66
# - p6(v2):    10     0     0 1.1e+02
# - p5(v1):  -5.2     0     0    27
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 62170513  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.1e+02  Error-roundoff 1.3e-13  _one-merge 1.2e-12
#   _near-inside 5.8e-12  Visible-distance 7.8e-13  U-max-coplanar 7.8e-13
#   Width-outside 1.6e-12  _wide-facet 4.7e-12  _maxoutside 1.6e-12
#
# ChemEnv failed for mp-1027023: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1095967: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   3.1 -9.4e-17 1.7e-16   9.4
# - p4(v4):  -3.1 -1.4e-17 -1.3e-16   9.4
# - p3(v3):   7.9 2.1e-16 -1.3e-16    62
# - p5(v2):    11     0     0 1.2e+02
# - p6(v1):  -5.5     0     0    30
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 66842859  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.2e+02  Error-roundoff 1.4e-13  _one-merge 1.3e-12
#   _near-inside 6.5e-12  Visible-distance 8.6e-13  U-max-coplanar 8.6e-13
#   Width-outside 1.7e-12  _wide-facet 5.2e-12  _maxoutside 1.7e-12
#
# ChemEnv failed for mp-1093927: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p0(v5):   6.5     0     0    42
# - p3(v4):     0     0     0     0
# - p2(v3):   9.8 -4.4e-16 -4.3e-16    96
# - p6(v2):    16 4.4e-16 4.3e-16 2.6e+02
# - p5(v1):  -3.2 3.5e-18 1.9e-17    10
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 67649595  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 2.6e+02  Error-roundoff 3.1e-13  _one-merge 2.8e-12
#   _near-inside 1.4e-11  Visible-distance 1.8e-12  U-max-coplanar 1.8e-12
#   Width-outside 3.7e-12  _wide-facet 1.1e-11  _maxoutside 3.7e-12
#
# ChemEnv failed for mp-1025819: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1028731: This structure is pathological, infinite vertex in the voronoi construction
# ChemEnv failed for mp-1178967: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1097659: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):     0     0     0     0
# - p4(v4):  -2.7 -1.1e-16 -7.9e-17   7.1
# - p3(v3):   7.8 1.1e-16 3.6e-16    61
# - p5(v2):    10     0     0 1.1e+02
# - p6(v1):  -5.2     0     0    27
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 79851477  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 1.1e+02  Error-roundoff 1.3e-13  _one-merge 1.2e-12
#   _near-inside 5.9e-12  Visible-distance 7.9e-13  U-max-coplanar 7.9e-13
#   Width-outside 1.6e-12  _wide-facet 4.8e-12  _maxoutside 1.6e-12
#
# ChemEnv failed for mp-672225: object of type 'NoneType' has no len()
# ChemEnv failed for mp-1096344: QH6239 Qhull precision error: initial Delaunay input sites are cocircular or cospherical.  Use option 'Qz' for the Delaunay triangulation or Voronoi diagram of cocircular/cospherical points; it adds a point "at infinity".  Alternatively use option 'QJ' to joggle the input.  Use option 'Qs' to search all points for the initial simplex.
#
# input sites with last coordinate projected to a paraboloid
# - p2(v5):   -30    11 0.081 9.9e+02
# - p1(v4):   -24    11   3.3 7e+02
# - p0(v3):   -27    11   1.7 8.3e+02
# - p5(v2):   -19    11   6.5 5e+02
# - p6(v1):   -35    11  -3.1 1.4e+03
#
# While executing:  | qhull v o Fv
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 83028000  voronoi  offFile  _pre-merge  _zero-centrum  Pgood  Fvoronoi
#   _max-width 8.6e+02  Error-roundoff 1.6e-12  _one-merge 1.4e-11
#   _near-inside 7.1e-11  Visible-distance 9.4e-12  U-max-coplanar 9.4e-12
#   Width-outside 1.9e-11  _wide-facet 5.6e-11  _maxoutside 1.9e-11
#
# Number of systems analyzed: 4922

# %%
# Number of systems where CrystalNN and ChemEnv disagree
sum(1 for k in data_chemenv.keys() if data_chemenv[k] != data.get(k, None))
# Out:
# 2914

# %%
crystalnets_options = jl.CrystalNets.Options(structure=jl.StructureType.Auto, clusterings=[jl.Clustering.EachVertex], bonding=jl.Bonding.Input, split_O_vertex=False)

def analyse_topology(material_id):
    res = jl.determine_topology(f"cif/{material_id}.cif", crystalnets_options)
    topologies = [(mult, jl.ndims(net[jl.Clustering.EachVertex].genome), str(net[jl.Clustering.EachVertex])) for net, mult in res]
    return topologies

# %%
analyse_topology("mp-1206677")
# Out:
# [(1, 3, 'pcu')]

# %%
jl.CrystalNets.toggle_export(False)
jl.CrystalNets.toggle_warning(False)

for material_id in tqdm(data.keys(), smoothing=0.01, mininterval=1):
    topo = analyse_topology(material_id)
    data[material_id]["topology"] = topo
# Out:
#   0%|          | 0/170455 [00:00<?, ?it/s]
# spglib: Indicated max size(=384) is less than number spglib: of symmetry operations(=768).
# spglib: Indicated max size(=384) is less than number spglib: of symmetry operations(=768).
# spglib: Indicated max size(=384) is less than number spglib: of symmetry operations(=768).
# spglib: Indicated max size(=384) is less than number spglib: of symmetry operations(=768).
# spglib: Indicated max size(=384) is less than number spglib: of symmetry operations(=768).

# %%
data["mp-1206677"]
# Out:
# {'material_id': 'mp-1206677',
#  'formula_pretty': 'Rb2O2',
#  'nelements': 2,
#  'theoretical': False,
#  'is_stable': None,
#  'crystal_system': 'Monoclinic',
#  'space_group': 11,
#  'coordination': {('O', 6), ('Rb', 6)},
#  'bonds': {('Rb', 'O')},
#  'topology': [(1, 3, 'pcu')]}

# %%
class SetEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, set):
            return list(obj)
        return json.JSONEncoder.default(self, obj)

with open("topo_data.json", "w") as file:
    json.dump(data, file, cls=SetEncoder)

# %%
# Compare with topology from ChemEnv bonding

crystalnets_options = jl.CrystalNets.Options(structure=jl.StructureType.Auto, clusterings=[jl.Clustering.EachVertex], bonding=jl.Bonding.Input, split_O_vertex=False)

def analyse_topology_chemenv(material_id):
    res = jl.determine_topology(f"cif_chemenv/{material_id}.cif", crystalnets_options)
    topologies = [(mult, jl.ndims(net[jl.Clustering.EachVertex].genome), str(net[jl.Clustering.EachVertex])) for net, mult in res]
    return topologies

for material_id in tqdm(data_chemenv.keys(), smoothing=0.01, mininterval=1):
    topo = analyse_topology_chemenv(material_id)
    data_chemenv[material_id]["topology"] = topo
# Out:
#   0%|          | 0/4922 [00:00<?, ?it/s]

# %%
# Number of systems where CrystalNN and ChemEnv disagree
sum(1 for k in data_chemenv.keys() if data_chemenv[k]["topology"] != data.get(k, {}).get("topology", None))
# Out:
# 2885

# %%
sum(1 for k in data_chemenv.keys() if data_chemenv[k] != data.get(k, None))
# Out:
# 2944

# %%
list(str(k) for k in data_chemenv.keys() if data_chemenv[k] != data.get(k, None) and 'UNKNOWN' not in data_chemenv[k]['topology'][0][2])[:10]
# Out:
# ['mp-978276',
#  'mp-1187858',
#  'mp-555874',
#  'mp-1114110',
#  'mp-2458',
#  'mp-1179374',
#  'mp-1226378',
#  'mp-1183942',
#  'mp-9472',
#  'mp-864947']

# %%
data_chemenv['mp-978276']
# Out:
# {'material_id': 'mp-978276',
#  'formula_pretty': 'Mg3Co',
#  'nelements': 2,
#  'theoretical': True,
#  'is_stable': None,
#  'crystal_system': 'Cubic',
#  'space_group': 225,
#  'coordination': {('Co', 14), ('Mg', 14)},
#  'bonds': {('Mg', 'Co'), ('Mg', 'Mg')},
#  'topology': [(1, 3, 'bcu-x')]}

# %%
data['mp-978276']
# Out:
# {'material_id': 'mp-978276',
#  'formula_pretty': 'Mg3Co',
#  'nelements': 2,
#  'theoretical': True,
#  'is_stable': None,
#  'crystal_system': 'Cubic',
#  'space_group': 225,
#  'coordination': {('Co', 8), ('Mg', 8)},
#  'bonds': {('Mg', 'Co'), ('Mg', 'Mg')},
#  'topology': [(1, 3, 'bcu')]}

# %%
with open("topo_data_chemenv.json", "w") as file:
    json.dump(data_chemenv, file, cls=SetEncoder)
